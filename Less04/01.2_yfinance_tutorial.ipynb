# %% [markdown]
# ## YAHOO FINANCE

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/yfinance.jpg" width="1200">

# %%
# !pip install yfinance --quiet
# !pip install mplfinance --quiet

# %% [markdown]
# ### Import Libraries

# %%
import yfinance as yf
import mplfinance as mpf
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Basic information

# %%
tsla = yf.Ticker("TSLA") #AAPL#
tsla.info
# Out:
# WARNING: No decryption keys could be extracted from JS file. Falling back to backup decrypt methods.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 tsla = yf.Ticker("TSLA") #AAPL#
# ----> 2 tsla.info
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\base.py:1475, in TickerBase.get_info(self, proxy)
#    1473 def get_info(self, proxy=None) -> dict:
#    1474     self._quote.proxy = proxy
# -> 1475     data = self._quote.info
#    1476     return data
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\scrapers\quote.py:95, in Quote.info(self)
# ...

# %%
print(f"Market Cap : {tsla.info['marketCap']}\n")
print(f"Employees : {tsla.info['fullTimeEmployees']}\n")
print(f"Business Summary : \n{tsla.info['longBusinessSummary']}")
# Out:
# Market Cap : 530912182272
#
# Employees : 99290
#
# Business Summary :
# ...

# %%
tsla.history(period='5d')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-11-15 00:00:00-05:00  195.880005  200.820007  192.059998  194.419998
# 2022-11-16 00:00:00-05:00  191.509995  192.570007  185.660004  186.919998
# 2022-11-17 00:00:00-05:00  183.960007  186.160004  180.899994  183.169998
# 2022-11-18 00:00:00-05:00  185.050003  185.190002  176.550003  180.190002
# 2022-11-21 00:00:00-05:00  175.850006  176.770004  168.039993  168.300003
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-11-15 00:00:00-05:00  91293800          0             0
# 2022-11-16 00:00:00-05:00  66567600          0             0
# 2022-11-17 00:00:00-05:00  64336000          0             0
# 2022-11-18 00:00:00-05:00  75904900          0             0
# 2022-11-21 00:00:00-05:00  68424363          0             0

# %%
#Remove actions
tsla.history(period='10d', actions=False)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-11-07 00:00:00-05:00  208.649994  208.899994  196.660004  197.080002
# 2022-11-08 00:00:00-05:00  194.020004  195.199997  186.750000  191.300003
# 2022-11-09 00:00:00-05:00  190.779999  195.889999  177.119995  177.589996
# 2022-11-10 00:00:00-05:00  189.899994  191.000000  180.029999  190.720001
# 2022-11-11 00:00:00-05:00  186.000000  196.520004  182.589996  195.970001
# 2022-11-14 00:00:00-05:00  192.770004  195.729996  186.339996  190.949997
# 2022-11-15 00:00:00-05:00  195.880005  200.820007  192.059998  194.419998
# 2022-11-16 00:00:00-05:00  191.509995  192.570007  185.660004  186.919998
# 2022-11-17 00:00:00-05:00  183.960007  186.160004  180.899994  183.169998
# 2022-11-18 00:00:00-05:00  185.050003  185.190002  176.550003  180.190002
#
#                               Volume
# Date
# 2022-11-07 00:00:00-05:00   93916500
# 2022-11-08 00:00:00-05:00  128803400
# ...

# %%
#Getting data using start date and end date
tsla=yf.Ticker('tsla')
#tsla.history(start="2021-02-20", end="2021-12-15", actions=False)4
tsla.history(actions=False)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-10 00:00:00-05:00  121.070000  122.760002  114.919998  118.849998
# 2023-01-11 00:00:00-05:00  122.089996  125.949997  120.510002  123.220001
# 2023-01-12 00:00:00-05:00  122.559998  124.129997  117.000000  123.559998
# 2023-01-13 00:00:00-05:00  116.550003  122.629997  115.599998  122.400002
# 2023-01-17 00:00:00-05:00  125.699997  131.699997  125.019997  131.490005
# 2023-01-18 00:00:00-05:00  136.559998  136.679993  127.010002  128.779999
# 2023-01-19 00:00:00-05:00  127.260002  129.990005  124.309998  127.169998
# 2023-01-20 00:00:00-05:00  128.679993  133.509995  127.349998  133.419998
# 2023-01-23 00:00:00-05:00  135.869995  145.380005  134.270004  143.750000
# 2023-01-24 00:00:00-05:00  143.000000  146.500000  141.100006  143.889999
# 2023-01-25 00:00:00-05:00  141.910004  146.410004  138.070007  144.429993
# 2023-01-26 00:00:00-05:00  159.970001  161.419998  154.759995  160.270004
# ...

# %%
type(tsla)
# Out:
# yfinance.ticker.Ticker

# %% [markdown]
# ## Pandas Dataframe_

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("tsla", start="2017-01-01", end="2022-02-09")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   14.324000   14.688667   14.064000   14.466000   14.466000
# 2017-01-04   14.316667   15.200000   14.287333   15.132667   15.132667
# 2017-01-05   15.094667   15.165333   14.796667   15.116667   15.116667
# 2017-01-06   15.128667   15.354000   15.030000   15.267333   15.267333
# 2017-01-09   15.264667   15.461333   15.200000   15.418667   15.418667
# ...                ...         ...         ...         ...         ...
# 2022-02-02  309.393341  310.500000  296.470001  301.886658  301.886658
# 2022-02-03  294.000000  312.333344  293.506653  297.046661  297.046661
# 2022-02-04  299.073334  312.166656  293.723328  307.773346  307.773346
# 2022-02-07  307.929993  315.923340  300.903320  302.446655  302.446655
# 2022-02-08  301.843323  308.763336  298.266663  307.333344  307.333344
#
#                Volume
# Date
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1285.000000  1285.000000  1285.000000  1285.000000  1285.000000
# mean     88.452130    90.410137    86.339287    88.483919    88.483919
# std     104.515047   106.865457   101.887586   104.487121   104.487121
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      20.024668    20.398666    19.633333    20.022667    20.022667
# 50%      23.311333    23.664667    22.925333    23.302000    23.302000
# 75%     147.306671   150.333328   142.933334   147.253326   147.253326
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  1.285000e+03
# mean   1.331383e+08
# std    8.989923e+07
# min    2.940180e+07
# 25%    7.540500e+07
# 50%    1.045470e+08
# 75%    1.553610e+08
# max    9.140820e+08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1285 entries, 2017-01-03 to 2022-02-08
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1285 non-null   float64
#  1   High       1285 non-null   float64
#  2   Low        1285 non-null   float64
#  3   Close      1285 non-null   float64
#  4   Adj Close  1285 non-null   float64
#  5   Volume     1285 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 70.3 KB

# %%
data.to_csv('tesla.csv')

# %% [markdown]
# ### Intraday plot

# %%
hist=tsla.history(start='2022-01-10', end='2023-02-10', 
                  interval='1m', actions=False)

mpf.plot(hist, type='candle', volume=True, style='yahoo', mav=(20),
        title='TSLA 2023-02-10', tight_layout=True)
# Out:
# TSLA: 1m data not available for startTime=1641790800 and endTime=1676005200. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       1 hist=tsla.history(start='2022-01-10', end='2023-02-10',
#       2                   interval='1m', actions=False)
# ----> 4 mpf.plot(hist, type='candle', volume=True, style='yahoo', mav=(20),
#       5         title='TSLA 2023-02-10', tight_layout=True)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\mplfinance\plotting.py:417, in plot(data, **kwargs)
#     414 # translate alias types:
#     415 config['type'] = _get_valid_plot_types(config['type'])
# --> 417 dates,opens,highs,lows,closes,volumes = _check_and_prepare_data(data, config)
# ...

# %% [markdown]
# ### Fetching multiple tickers

# %%
data = yf.download("AMZN AAPL TSLA", period="ytd",
        group_by='ticker', actions=False)
amzn=data["AMZN"]
aapl=data["AAPL"]
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
amzn.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-01-03  85.459999  86.959999  84.209999  85.820000  85.820000  76706000
# 2023-01-04  86.550003  86.980003  83.360001  85.139999  85.139999  68885100
# 2023-01-05  85.330002  85.419998  83.070000  83.120003  83.120003  67930800
# 2023-01-06  83.029999  86.400002  81.430000  86.080002  86.080002  83219100
# 2023-01-09  87.459999  89.480003  87.080002  87.360001  87.360001  65266100

# %% [markdown]
# ### Covnvert data into csv

# %%
amzn.to_csv('amzn.csv')

# %% [markdown]
# ## Other functions in Ticker Module

# %%
#actions
aapl=yf.Ticker('AAPL')
aapl.actions.tail(5)
# Out:
#                            Dividends  Stock Splits
# Date
# 2021-11-05 00:00:00-04:00       0.22           0.0
# 2022-02-04 00:00:00-05:00       0.22           0.0
# 2022-05-06 00:00:00-04:00       0.23           0.0
# 2022-08-05 00:00:00-04:00       0.23           0.0
# 2022-11-04 00:00:00-04:00       0.23           0.0

# %%
#dividends
aapl.dividends.tail()
# Out:
# Date
# 2021-11-05 00:00:00-04:00    0.22
# 2022-02-04 00:00:00-05:00    0.22
# 2022-05-06 00:00:00-04:00    0.23
# 2022-08-05 00:00:00-04:00    0.23
# 2022-11-04 00:00:00-04:00    0.23
# Name: Dividends, dtype: float64

# %%
#splits
aapl.splits.tail()
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
#major_holders
aapl.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  61.27%       % of Shares Held by Institutions
# 2  61.32%        % of Float Held by Institutions
# 3    5577  Number of Institutions Holding Shares

# %%
#institutional_holders
aapl.institutional_holders
# Out:
#                           Holder      Shares Date Reported   % Out  \
# 0     Vanguard Group, Inc. (The)  1272378901    2022-09-29  0.0804
# 1                 Blackrock Inc.  1020245185    2022-09-29  0.0645
# 2        Berkshire Hathaway, Inc   894802319    2022-09-29  0.0566
# 3       State Street Corporation   591543874    2022-09-29  0.0374
# 4                       FMR, LLC   350900116    2022-09-29  0.0222
# 5  Geode Capital Management, LLC   279758518    2022-09-29  0.0177
# 6  Price (T.Rowe) Associates Inc   224863541    2022-09-29  0.0142
# 7                 Morgan Stanley   182728771    2022-09-29  0.0115
# 8     Northern Trust Corporation   176084862    2022-09-29  0.0111
# 9    Bank of America Corporation   142260591    2022-09-29  0.0090
#
#           Value
# 0  190812297228
# 1  153001065432
# 2  134189026491
# 3   88710874898
# 4   52622734610
# 5   41953985127
# 6   33721660102
# 7   27402919473
# 8   26406565684
# 9   21334109008

# %%
#sustainability
#aapl.sustainability

# %%
#Analyst recommendations
aapl.recommendations.tail()
# Out:
#                                   Firm      To Grade From Grade Action
# Date
# 2022-10-28 13:19:17            Wedbush    Outperform              main
# 2022-11-07 12:39:27           Barclays  Equal-Weight              main
# 2022-11-07 13:08:30  B of A Securities       Neutral              main
# 2022-11-08 12:14:23     Morgan Stanley    Overweight              main
# 2022-11-08 12:17:03                UBS           Buy              main

# %%
# Show the upcoming events
aapl.calendar
# Out:
#                                     0                    1
# Earnings Date     2023-01-25 10:59:00  2023-01-30 12:00:00
# Earnings Average                 2.04                 2.04
# Earnings Low                     1.89                 1.89
# Earnings High                    2.13                 2.13
# Revenue Average          125689000000         125689000000
# Revenue Low              117857000000         117857000000
# Revenue High             129379000000         129379000000

# %%
# Show ISIN code
aapl.isin

# %%
# Available option expiration dates
aapl.options
# Out:
# ('2023-02-10',
#  '2023-02-17',
#  '2023-02-24',
#  '2023-03-03',
#  '2023-03-10',
#  '2023-03-17',
#  '2023-03-24',
#  '2023-04-21',
#  '2023-05-19',
#  '2023-06-16',
#  '2023-07-21',
#  '2023-08-18',
#  '2023-09-15',
#  '2023-10-20',
#  '2023-12-15',
#  '2024-01-19',
#  '2024-03-15',
#  '2024-06-21',
#  '2024-09-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19')

# %%
aapl.option_chain('2023-02-10').puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL230210P00050000 2023-02-07 15:23:54+00:00    50.0       0.01    0.00
# 1   AAPL230210P00055000 2023-01-30 19:39:14+00:00    55.0       0.01    0.00
# 2   AAPL230210P00060000 2023-02-01 15:44:21+00:00    60.0       0.02    0.00
# 3   AAPL230210P00065000 2023-01-23 15:08:07+00:00    65.0       0.01    0.00
# 4   AAPL230210P00070000 2023-01-23 15:07:57+00:00    70.0       0.01    0.00
# ..                  ...                       ...     ...        ...     ...
# 62  AAPL230210P00180000 2023-02-10 14:40:44+00:00   180.0      30.20   30.10
# 63  AAPL230210P00185000 2023-02-07 17:47:46+00:00   185.0      31.00   35.15
# 64  AAPL230210P00190000 2023-02-09 15:21:48+00:00   190.0      36.50   40.10
# 65  AAPL230210P00245000 2023-02-07 17:50:13+00:00   245.0      91.00   95.05
# 66  AAPL230210P00250000 2023-02-10 16:57:32+00:00   250.0     100.00  100.25
#
# ...
